# %%
import demoji
import pandas as pd
 
demoji.download_codes()
# Out:
# ...
# ... OK (Got response in 0.39 seconds)
# Writing emoji data to C:\Users\grand\.demoji\codes.json ...
# ... OK

# %%
dataset = pd.read_csv('restaurant_reviews.csv')
t = dataset['Reviews'] 
rev = ''.join(t)
demoji.findall(rev)
# Out:
# {'👍🏼': 'thumbs up: medium-light skin tone',
#  '🎶': 'musical notes',
#  '✨': 'sparkles',
#  '😔': 'pensive face',
#  '💕': 'two hearts',
#  '🌾': 'sheaf of rice',
#  '🤴🏻': 'prince: light skin tone',
#  '🎵': 'musical note',
#  '🧡': 'orange heart',
#  '🥰': 'smiling face with hearts',
#  '😞': 'disappointed face',
#  '🥯': 'bagel',
#  '👊': 'oncoming fist',
#  '👌': 'OK hand',
#  '🍄': 'mushroom',
#  '🎂': 'birthday cake',
#  '😌': 'relieved face',
#  '😢': 'crying face',
#  '🤜': 'right-facing fist',
#  '🍗': 'poultry leg',
#  '😆': 'grinning squinting face',
#  '🍔': 'hamburger',
#  '🇵🇪': 'flag: Peru',
#  '💖': 'sparkling heart',
#  '💚': 'green heart',
#  '😪': 'sleepy face',
#  '👍🏻': 'thumbs up: light skin tone',
#  '🎉': 'party popper',
#  '🥩': 'cut of meat',
#  '💯': 'hundred points',
#  '🤕': 'face with head-bandage',
#  '🤵🏻': 'person in tuxedo: light skin tone',
#  '👸🏼': 'princess: medium-light skin tone',
#  '✌🏼': 'victory hand: medium-light skin tone',
#  '🥓': 'bacon',
# ...
