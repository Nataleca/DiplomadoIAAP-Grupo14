# %%
import spacy as sp

import os
import pandas as pd
import numpy as np
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly as py
import plotly.graph_objs as go
import gensim
from gensim import corpora, models, similarities
import logging
import tempfile
from nltk.corpus import stopwords
from string import punctuation
from collections import OrderedDict
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

init_notebook_mode(connected=True) #do not miss this line

import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
datafile = 'restaurant_reviews.csv'
df = pd.read_csv(datafile, parse_dates=[0], infer_datetime_format=True)
df['reviews_limpios'] = df['reviews_limpios'].astype(str)
df['reviews_limpios']
# Out:
# 0        experiencia almozar típico restaurante colombi...
# 1        restaurante agradable antiguo familiar persona...
# 2        llegamos tarde horas público atendieron bien c...
# 3        hace años disfrutaba almuerzo agradable restau...
# 4        lugar típico cocina colombiana puede dejar vis...
#                                ...
# 44178    ambiente exclusivo excelente comida siga recom...
# 44179    gran experiencia puede explicar palabras simpl...
# 44180    andrés usted sólo sabor mejores platos colombi...
# 44181    andrés carne duda lugares fantásticos mundo bo...
# 44182    encontrado restaurante mundo fundada músico lo...
# Name: reviews_limpios, Length: 44183, dtype: object

# %%
from nltk.corpus import stopwords

spanish_stopwords = set(stopwords.words('spanish'))

def tokenize_phrase(phrase):
    parsed_phrase = nlp(phrase)
    for token in parsed_phrase:
        if token.is_punct or token.is_stop or token.text.lower() in spanish_stopwords:
            continue
        yield token.lemma_.lower()

# %%
from collections import Counter
word_counter = Counter()
for amlo_phrase in df['reviews_limpios']:
    word_counter.update(tokenize_phrase(amlo_phrase))

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,5))
ax = fig.gca()

labels, values = zip(*word_counter.most_common(15))

indexes = np.arange(len(labels))
width = 1

ax.bar(indexes, values, 0.5)
ax.set_xticks(indexes)
ax.set_xticklabels( labels, rotation=90, fontsize=20)
ax.set_title("Las 20 más frecuentemente usadas\nen la opinion de restaurantes", fontsize=20)
plt.show()

# %%
corpus=[]
a=[]
for i in range(len(df['reviews_limpios'])):
        a=df['reviews_limpios'][i]
        corpus.append(a)
        
corpus[0:10]
# Out:
# ['experiencia almozar típico restaurante colombiano centro bogota platos deliciosos además mezcla sabores cultura puede dejar probar',
#  'restaurante agradable antiguo familiar personal agradó bastante servicio bueno comida típica colombiana bien lograda clásico tour gastronómico bogotá recomendado',
#  'llegamos tarde horas público atendieron bien comimos deliciosos platos típicos bogotá música fondo encantó parece ayuda tradición lugar años prestigio',
#  'hace años disfrutaba almuerzo agradable restaurante ambiente gusto atención recetas excelentes',
#  'lugar típico cocina colombiana puede dejar visitar encuentra bogotá ciudad cierto vive tiempos suerte inflación culinaria apertura decenas nuevos locales muchas veces excesivamente pretenciosos excesivamente costosos gastronómicamente',
# ...

# %%
TEMP_FOLDER = tempfile.gettempdir()
print('Folder "{}" will be used to save temporary dictionary and corpus.'.format(TEMP_FOLDER))

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# Folder "C:\Users\grand\AppData\Local\Temp" will be used to save temporary dictionary and corpus.

# %%
# removing common words and tokenizing

stoplist = stopwords.words('spanish') + list(punctuation) 

texts = [[word for word in str(document).lower().split() if word not in stoplist] for document in corpus]

dictionary = corpora.Dictionary(texts)
dictionary.save(os.path.join(TEMP_FOLDER, 'elon.dict'))  # store the dictionary, for future reference

#print(dictionary)
#print(dictionary.token2id)
# Out:
# 2021-05-13 19:15:02,605 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2021-05-13 19:15:02,926 : INFO : adding document #10000 to Dictionary(14982 unique tokens: ['además', 'almozar', 'bogota', 'centro', 'colombiano']...)
# 2021-05-13 19:15:03,215 : INFO : adding document #20000 to Dictionary(20796 unique tokens: ['además', 'almozar', 'bogota', 'centro', 'colombiano']...)
# 2021-05-13 19:15:03,494 : INFO : adding document #30000 to Dictionary(24800 unique tokens: ['además', 'almozar', 'bogota', 'centro', 'colombiano']...)
# 2021-05-13 19:15:03,762 : INFO : adding document #40000 to Dictionary(28358 unique tokens: ['además', 'almozar', 'bogota', 'centro', 'colombiano']...)
# 2021-05-13 19:15:03,887 : INFO : built Dictionary(30045 unique tokens: ['además', 'almozar', 'bogota', 'centro', 'colombiano']...) from 44183 documents (total 670491 corpus positions)
# ...

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
corpora.MmCorpus.serialize(os.path.join(TEMP_FOLDER, 'elon.mm'), corpus)
# Out:
# 2021-05-13 19:15:51,244 : INFO : storing corpus in Matrix Market format to C:\Users\grand\AppData\Local\Temp\elon.mm
# 2021-05-13 19:15:51,245 : INFO : saving sparse matrix to C:\Users\grand\AppData\Local\Temp\elon.mm
# 2021-05-13 19:15:51,246 : INFO : PROGRESS: saving document #0
# 2021-05-13 19:15:51,285 : INFO : PROGRESS: saving document #1000
# 2021-05-13 19:15:51,314 : INFO : PROGRESS: saving document #2000
# 2021-05-13 19:15:51,342 : INFO : PROGRESS: saving document #3000
# 2021-05-13 19:15:51,371 : INFO : PROGRESS: saving document #4000
# 2021-05-13 19:15:51,403 : INFO : PROGRESS: saving document #5000
# 2021-05-13 19:15:51,432 : INFO : PROGRESS: saving document #6000
# 2021-05-13 19:15:51,461 : INFO : PROGRESS: saving document #7000
# 2021-05-13 19:15:51,493 : INFO : PROGRESS: saving document #8000
# 2021-05-13 19:15:51,522 : INFO : PROGRESS: saving document #9000
# 2021-05-13 19:15:51,550 : INFO : PROGRESS: saving document #10000
# ...

# %%
tfidf = models.TfidfModel(corpus)
# Out:
# 2021-05-13 19:16:36,141 : INFO : collecting document frequencies
# 2021-05-13 19:16:36,142 : INFO : PROGRESS: processing document #0
# 2021-05-13 19:16:36,187 : INFO : PROGRESS: processing document #10000
# 2021-05-13 19:16:36,252 : INFO : PROGRESS: processing document #20000
# 2021-05-13 19:16:36,308 : INFO : PROGRESS: processing document #30000
# 2021-05-13 19:16:36,355 : INFO : PROGRESS: processing document #40000
# 2021-05-13 19:16:36,374 : INFO : calculating IDF weights for 44183 documents and 30045 features (647725 matrix non-zeros)

# %%
corpus_tfidf = tfidf[corpus]

# %%
total_topics = 5

# %%
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=total_topics)
corpus_lda = lda[corpus_tfidf]
# Out:
# 2021-05-13 19:17:25,375 : INFO : using symmetric alpha at 0.2
# 2021-05-13 19:17:25,376 : INFO : using symmetric eta at 0.2
# 2021-05-13 19:17:25,381 : INFO : using serial LDA version on this node
# 2021-05-13 19:17:25,399 : INFO : running online (single-pass) LDA training, 5 topics, 1 passes over the supplied corpus of 44183 documents, updating model once every 2000 documents, evaluating perplexity every 20000 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-05-13 19:17:25,400 : INFO : PROGRESS: pass 0, at document #2000/44183
# 2021-05-13 19:17:27,131 : INFO : merging changes from 2000 documents into a model of 44183 documents
# 2021-05-13 19:17:27,153 : INFO : topic #0 (0.200): 0.032*"comida" + 0.018*"restaurante" + 0.016*"buena" + 0.014*"lugar" + 0.012*"buen" + 0.011*"servicio" + 0.010*"bien" + 0.010*"atención" + 0.010*"ambiente" + 0.008*"platos"
# ...

# %%
lda.show_topics(total_topics,5)
# Out:
# [(0,
#   '0.041*"comida" + 0.024*"restaurante" + 0.023*"bogotá" + 0.019*"lugar" + 0.016*"buena"'),
#  (1,
#   '0.023*"comida" + 0.015*"servicio" + 0.014*"pena" + 0.014*"carne" + 0.014*"restaurante"'),
#  (2,
#   '0.023*"lugar" + 0.023*"servicio" + 0.015*"excelente" + 0.015*"original" + 0.013*"atención"'),
#  (3,
#   '0.011*"experiencia" + 0.009*"divertida" + 0.008*"andres" + 0.007*"cada" + 0.006*"servicio"'),
#  (4,
#   '0.061*"comida" + 0.044*"lugar" + 0.042*"buena" + 0.035*"excelente" + 0.032*"ambiente"')]

# %%
data_lda = {i: OrderedDict(lda.show_topic(i,25)) for i in range(total_topics)}

# %%
df_lda = pd.DataFrame(data_lda)
df_lda = df_lda.fillna(0).T
print(df_lda.shape)
# Out:
# (5, 82)

# %%
df_lda
# Out:
#      comida  restaurante    bogotá     lugar     buena  servicio    platos  \
# 0  0.040633     0.024041  0.023167  0.018871  0.015797  0.013860  0.013063
# 1  0.023336     0.013522  0.000000  0.009526  0.006805  0.015449  0.000000
# 2  0.012229     0.000000  0.000000  0.022942  0.007729  0.022922  0.008227
# 3  0.004662     0.003950  0.000000  0.004259  0.000000  0.005968  0.005408
# 4  0.060806     0.008697  0.000000  0.043570  0.041827  0.020784  0.000000
#
#       mejor  ambiente      bien  ...  esperando     quedé    música  \
# 0  0.012996  0.011749  0.011336  ...   0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.006246  ...   0.000000  0.000000  0.000000
# 2  0.000000  0.010997  0.000000  ...   0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...   0.003439  0.003235  0.000000
# 4  0.007971  0.032409  0.006573  ...   0.000000  0.000000  0.020449
#
#    deliciosa    amigos  recomendado     noche     super      rica     baile
# ...

# %%
g=sns.clustermap(df_lda.corr(), center=0, standard_scale=1, cmap="RdBu", metric='cosine', linewidths=.75, figsize=(15, 15))
plt.setp(g.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()
# Out:
# 2021-05-13 19:21:25,063 : INFO : NumExpr defaulting to 8 threads.

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

panel = gensimvis.prepare(lda, corpus_lda, dictionary, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 0      150.222153  -72.269554       1        1  54.747957
# 4       51.163364 -159.968018       2        1  11.364823
# 3      -73.144554   21.523815       3        1  11.329758
# 2      -66.410133 -110.606438       4        1  11.318989
# 1       54.417324   12.443444       5        1  11.238473, topic_info=          Term         Freq        Total Category  logprob  loglift
# 25      comida  1488.000000  1488.000000  Default  30.0000  30.0000
# 156      buena   671.000000   671.000000  Default  29.0000  29.0000
# 42       lugar   858.000000   858.000000  Default  28.0000  28.0000
# 51    ambiente   506.000000   506.000000  Default  27.0000  27.0000
# 108  excelente   536.000000   536.000000  Default  26.0000  26.0000
# ..         ...          ...          ...      ...      ...      ...
# 107    calidad    29.474124   254.286499   Topic5  -5.1268   0.0309
# ...

# %%
#from sklearn.feature_extraction.text import CountVectorizer
#frequency_vectorizer = CountVectorizer(analyzer=tokenize_phrase)

#frequency_vectorizer.fit(df['reviews_limpios'])
#frequency_vectors = frequency_vectorizer.transform(df['reviews_limpios'])

# %%
#from sklearn.feature_extraction.text import CountVectorizer
#one_hot_vectorizer = CountVectorizer(analyzer=tokenize_phrase, binary=True)

#one_hot_vectorizer.fit(df['reviews_limpios'])
#one_hot_vectors = one_hot_vectorizer.transform(df['reviews_limpios'])
